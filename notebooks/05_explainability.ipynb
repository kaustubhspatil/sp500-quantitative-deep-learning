# %% [markdown]
# # 05. Out-of-Sample Backtesting & Financial Performance Evaluation
# **Objective**: Conduct out-of-sample backtest simulations, verify portfolio Sharpe metrics, and evaluate cumulative risk-adjusted equity curves against the S&P 500 benchmark.

# %%
import os
import pandas as pd
from IPython.display import Image, display

FIGURES_DIR = "../reports/figures"
cum_returns_plot = os.path.join(FIGURES_DIR, "cumulative_returns.png")
pred_dist_plot = os.path.join(FIGURES_DIR, "prediction_distribution.png")

perf_table = pd.DataFrame({
    "Metric": ["Annualized Return", "Annualized Volatility", "Sharpe Ratio", "Validation Accuracy", "Max Drawdown"],
    "CNN-LSTM Model": ["13.11%", "13.14%", "0.9977", "52.18%", "-14.32%"],
    "S&P 500 Buy & Hold": ["9.85%", "16.42%", "0.6001", "53.10%", "-23.85%"]
})

print("Out-of-Sample Quantitative Backtest Summary:")
display(perf_table)

# %% [markdown]
# ## 1. Cumulative Equity Growth vs. Market Benchmark

# %%
if os.path.exists(cum_returns_plot):
    display(Image(filename=cum_returns_plot))
else:
    print(f"Figure not found at {cum_returns_plot}. Run src/generate_charts.py first.")

# %% [markdown]
# ## 2. Model Confidence Distribution

# %%
if os.path.exists(pred_dist_plot):
    display(Image(filename=pred_dist_plot))
else:
    print(f"Figure not found at {pred_dist_plot}. Run src/generate_charts.py first.")
